# %%
import sqlite3
import pandas as pd
import numpy as np
#prices_file = pd.read_csv('Prices_table.csv')

# %%
# Create a db file name database.sqlite
db = sqlite3.connect("prices_csv.sqlite")
#prices_file.to_sql('prices', db)

# %%
prices_file = pd.read_csv('stats_table.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-102-79b2bef81821> in <module>()
# ----> 1 prices_file = pd.read_csv('stats_table.csv')
#
# ...

# %%
prices_file = pd.read_csv('Prices_table.csv')

# %%
prices_file.head()
# Out:
#           AKS     AM    COG    CPE      D    DVN    EQT   ESV   FOXF   GIG  \
# Date
# 9/21/16  4.72  26.68  25.24   14.9  76.75  42.17  74.16  7.09  21.82  2.33
# 9/20/16   4.3  25.57  24.52  14.15  75.63  40.66  72.76  6.64  20.45  2.28
# 9/19/16   4.3  25.52  24.35  14.37   75.9  40.85  71.23  6.74  20.53  2.22
# 9/16/16  4.11  25.04   24.3  14.48  75.06  40.99  70.51  6.87  20.88  2.18
# 9/15/16  4.06  25.16  25.04  14.19  74.45   40.9  71.44  6.99  20.84  2.19
#
#           ...       QEP     SABR     SE  SPWH    SRC    SWN  SYRG    WGP  \
# Date      ...
# 9/21/16   ...     18.07    27.07  42.67  9.82  13.38  14.68   6.3  39.63
# 9/20/16   ...     17.07    26.71     42  9.64  13.15  14.25  5.88  38.66
# 9/19/16   ...     17.09    26.92  42.31  9.78  13.11  13.86  6.08  38.18
# 9/16/16   ...     17.06    26.87  42.46  9.77  12.96  13.68  6.14  37.55
# 9/15/16   ...     16.88  27.4373  42.22  9.67  13.04  14.08  6.23     37
#
#            USO      SPY
# Date
# ...

# %%
prices_file.tail()
# Out:
#            AKS       AM      COG   CPE        D      DVN      EQT      ESV  \
# Date
# 10/22/15  2.64  22.6402   22.011  8.65  71.6686  43.8369  68.1949  16.4022
# 10/21/15  2.53  23.1499  22.2601  8.34  71.1202  43.0043   74.144  16.0072
# 10/20/15  2.71  23.5346  23.3562  8.43  70.8989  44.7577  75.6712  16.4515
# 10/19/15  2.77  23.8039  23.0273  8.14   70.591  44.3561  75.0124  15.8788
# 10/16/15  2.86  24.3137   23.127  8.76  70.3697  45.4826  76.3001  16.3824
#
#            FOXF   GIG   ...         QEP     SABR       SE   SPWH      SRC  \
# Date                    ...
# 10/22/15   16.5  2.27   ...     15.3791  29.2846  27.0658  11.36  9.61718
# 10/21/15  16.71  2.22   ...     15.7287  28.8718  27.2937   12.1  9.45515
# 10/20/15  17.15  2.17   ...     16.2979  29.2944  27.5217  12.11  9.54093
# 10/19/15  17.38   2.1   ...     16.1181  29.2649  27.6451  12.13  9.51234
# 10/16/15  17.66  1.97   ...     16.0782  29.0684   27.873   12.1  9.31218
#
# ...

# %%
prices_file_added = pd.read_csv('Secondary_prices_added.csv')

# %%
#prices_file_added.head()
type(prices_added)
# Out:
# pandas.core.frame.DataFrame

# %%
prices_added.tail()
# Out:
#            TAST   INCR LSCC'        X      AEP      SPY
# Date
# 10/22/15  12.37  38.24  4.56  11.0865  56.5546  199.756
# 10/21/15  12.34  40.39  4.31  10.6544  56.3348  196.437
# 10/20/15  12.59  42.06  4.69  11.1847  56.0672  197.664
# 10/19/15  12.48   42.8  4.65  11.8426  56.0002  197.917
# 10/16/15  12.52  42.25  4.51   12.255  55.9525  197.819

# %%
#prices_file_added_no_date = prices_file_added.T
#prices_added = prices_file_added_no_date.T
prices_added = prices_added.T

# %%
prices_file.index
# Out:
# Index(['9/21/16', '9/20/16', '9/19/16', '9/16/16', '9/15/16', '9/14/16',
#        '9/13/16', '9/12/16', '9/9/16', '9/8/16',
#        ...
#        '10/29/15', '10/28/15', '10/27/15', '10/26/15', '10/23/15', '10/22/15',
#        '10/21/15', '10/20/15', '10/19/15', '10/16/15'],
#       dtype='object', name='Date', length=235)

# %%
prices_added.index
# Out:
# Index(['9/21/16', '9/20/16', '9/19/16', '9/16/16', '9/15/16', '9/14/16',
#        '9/13/16', '9/12/16', '9/9/16', '9/8/16',
#        ...
#        '10/29/15', '10/28/15', '10/27/15', '10/26/15', '10/23/15', '10/22/15',
#        '10/21/15', '10/20/15', '10/19/15', '10/16/15'],
#       dtype='object', name='Date', length=235)

# %%
#from datetime import datetime
#combined = pd.concat([prices_file,prices_added], axis =1)
#temp_lscc = combined['LSCC\'']
#combined['LSCC']= temp_lscc 
#combined= combined[:235]
combined.tail()
# Out:
#            AKS       AM      COG   CPE        D      DVN      EQT      ESV  \
# Date
# 10/22/15  2.64  22.6402   22.011  8.65  71.6686  43.8369  68.1949  16.4022
# 10/21/15  2.53  23.1499  22.2601  8.34  71.1202  43.0043   74.144  16.0072
# 10/20/15  2.71  23.5346  23.3562  8.43  70.8989  44.7577  75.6712  16.4515
# 10/19/15  2.77  23.8039  23.0273  8.14   70.591  44.3561  75.0124  15.8788
# 10/16/15  2.86  24.3137   23.127  8.76  70.3697  45.4826  76.3001  16.3824
#
#            FOXF   GIG  ...     SWN   SYRG      WGP    USO      SPY   TAST  \
# Date                   ...
# 10/22/15   16.5  2.27  ...   11.67   11.1  40.5869  14.51  200.933  12.37
# 10/21/15  16.71  2.22  ...    12.4  10.86   41.485  14.43  197.595  12.34
# 10/20/15  17.15  2.17  ...   13.09  11.28  43.2048  14.73  198.829  12.59
# 10/19/15  17.38   2.1  ...   12.99  11.16   43.587  14.83  199.083  12.48
# 10/16/15  17.66  1.97  ...   13.14  11.35  43.7876  15.22  198.985  12.52
#
# ...

# %%
#stats_file = pd.read_csv('Secondary_Stats.csv')
#print(combined.columns)
#temp_combined
combined_prices = temp_combined

# %%
comp_ratios = {}
for i in range(len(stats_file.index)):
    ticker = stats_file.index[i]
    comp = stats_file.ix[ticker][5]
    comp_ratios[ticker] = (combined_prices[ticker]/combined_prices[comp])

# %%
from datetime import datetime
stats_file.ix[2][1]
# Out:
# '2/23/16'

# %%
adj_date = list()
weekday = list()
for i in range(len(stats_file.index)):
    temp_date_string = stats_file.ix[i][1]
    temp_date = datetime.strptime(temp_date_string, '%m/%d/%y')
    adj_date.append(temp_date)
    weekday.append(temp_date.weekday())
weekday
# Out:
# [4, 3, 1, 4, 1, 3, 4, 4, 4, 4, 3, 4, 1, 1, 1, 0, 4, 1, 2, 1, 2, 6, 1]

# %%
#day_prior['SYRG'] =  day_prior['SYRG']- timedelta(1)
stats_file['Day_Prior'] = day_prior

# %%
from datetime import timedelta
#stats_file['Adj_Date'] = adj_date
#stats_file['Week_day'] = weekday
temp = stats_file['Adj_Date']
day_prior = temp - timedelta(1)
stats_file['Day_Prior'] = day_prior

# %%
#stats_file['recent_date'] = datetime.strptime("9/21/16", '%m/%d/%y')
#stats_file['Last_day_index'] = stats_file['recent_date'] - (stats_file['Day_Prior']) 
#stats_file.ix['AKS'][8] 
#string_date = (stats_file.ix['AKS'][8]).strftime('%m/%d/%y')
#string_date
#comp_ratios['WGP']['6/13/16']
#aks_temp.index
#stats_file['Day_Prior']

setup_ratios = {'AKS': .27368643673642035,
'AM':     2.993718826405868,
'COG':     0.3573522892421874,
'CPE':    0.3691311187732801,
'D':      1.1282216612678757,
'DVN':     1.2698352121595948,
'EQT':     2.2085557405136336,
'ESV':    1.4335605156037992,
'FOXF':    0.0883985248327803,
'GIG':    0.4463373083475298,
'GPOR':    0.45755959964657106,
'HES':     2.770757761966365,
'MTDR':   0.8307601216195932,
'PE':      2.594936593785961,
'PRAH':   1.0305585030440778,
'QEP':     1.7755775577557757,
'SABR':    0.14246243332784198,
'SE':     2.663867098384159,
'SPWH':   0.8183730715287517,
'SRC':    0.385498103215725,
'SWN':    0.7838600893826236,
'SYRG':   0.605087934697435,
'WGP':    0.7247882666936262}

# %%
## PROPER WAY TO DEAL WITH SETTING A VALUE ON A COPY OF DF WARNING
#stats_file.loc['SRC', 'Transaction_Volume'] = 30
stats_file.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-776492c11372> in <module>()
#       1 ## PROPER WAY TO DEAL WITH SETTING A VALUE ON A COPY OF DF WARNING
#       2 #stats_file.loc['SRC', 'Transaction_Volume'] = 30
# ----> 3 stats_file.head
#
# NameError: name 'stats_file' is not defined

# %%
comp_ratios_normed = {}
for i in range(len(stats_file.index)):
    ticker = stats_file.index[i]
    comp_ratios_normed[ticker] = comp_ratios[ticker]/setup_ratios[ticker]
# Out:
# {'AKS': Date
#  9/21/16     0.965805
#  9/20/16     0.946489
#  9/19/16     0.936917
#  9/16/16     0.946177
#  9/15/16     0.925936
#  9/14/16     0.915673
#  9/13/16     0.909513
#  9/12/16     0.895185
#  9/9/16      0.890402
#  9/8/16       0.85647
#  9/7/16      0.843031
#  9/6/16      0.881829
#  9/2/16      0.843001
#  9/1/16      0.833722
#  8/31/16     0.840309
#  8/30/16      0.83354
#  8/29/16     0.848717
#  8/26/16     0.847657
#  8/25/16     0.854081
#  8/24/16     0.847641
#  8/23/16     0.854216
#  8/22/16     0.839185
#  8/19/16     0.839292
#  8/18/16     0.868231
#  8/17/16     0.872638
#  8/16/16     0.884741
#  8/15/16     0.875433
#  8/12/16     0.874803
#  8/11/16      0.86238
#  8/10/16     0.838676
#                ...
#  11/27/15     1.05413
#  11/25/15     1.05741
#  11/24/15     1.04238
#  11/23/15     1.06467
#  11/20/15     1.00454
#  11/19/15     0.97675
#  11/18/15    0.973519
#  11/17/15    0.956167
#  11/16/15    0.966378
#  11/13/15    0.968526
# ...

# %%
stats_file.ix['QEP']
# Out:
# Stock                                 QEP
# Date                              2/29/16
# Transaction_Price                      10
# Transaction_Volume                     38
# Transaction_$                         380
# Comp                                  CPE
# Adj_Date              2016-02-29 00:00:00
# Week_day                                0
# Day_Prior             2016-02-28 00:00:00
# Name: QEP, dtype: object

# %%
# ESTABLISHING A ZERO-FILLED DF TO HOLD CUMSUM VOLUMES
#volumes_file = pd.read_csv('Volumes_table.csv')

#zero_data = np.zeros(shape=(len(volumes_file),len(volumes_file.columns)))
#volumes_cum_sum = pd.DataFrame(zero_data, columns=volumes_file.columns)
#volumes_cum_sum['Date'] = volumes_file['Date']
#del volumes_cum_sum['SPY']
#del volumes_cum_sum['USO']
volumes_cum_sum.head()
# Out:
#                      AKS          AM          COG          CPE            D  \
# Date
# 2016-09-21  1.389125e+09  63937100.0  946925300.0  550572100.0  332646500.0
# 2016-09-20  1.365033e+09  63604000.0  940827400.0  546467600.0  329862100.0
# 2016-09-19  1.358721e+09  63113100.0  935347600.0  543541500.0  327430500.0
# 2016-09-16  1.347933e+09  62679900.0  931850500.0  540525800.0  325297200.0
# 2016-09-15  1.336726e+09  62034700.0  924840300.0  533414100.0  320552800.0
#
#                      DVN          EQT           ESV        FOXF         GIG  \
# Date
# 2016-09-21  1.616570e+09  269463700.0  1.039501e+09  28480800.0  57714200.0
# 2016-09-20  1.611824e+09  267734700.0  1.026484e+09  25857300.0  57168400.0
# 2016-09-19  1.607936e+09  265980400.0  1.018584e+09  25788800.0  56697000.0
# 2016-09-16  1.604067e+09  264904500.0  1.010146e+09  25675400.0  56399100.0
# 2016-09-15  1.598477e+09  262593800.0  9.961387e+08  25367100.0  55815800.0
#
# ...

# %%
#  SETTING VOLUMES INDEX TO RUN IX QUERIES AGAINST
#volumes_file.index = volumes_file['Date']
#del volumes_file['Date']
volumes_file.head()
# Out:
#                  AKS      AM      COG      CPE        D      DVN      EQT  \
# Date
# 2016-09-21  24092400  333100  6097900  4104500  2784400  4746400  1729000
# 2016-09-20   6311200  490900  5479800  2926100  2431600  3887500  1754300
# 2016-09-19  10788200  433200  3497100  3015700  2133300  3869200  1075900
# 2016-09-16  11206900  645200  7010200  7111700  4744400  5589600  2310700
# 2016-09-15  12405400  350400  5422800  5171700  2145100  4470500  1193400
#
#                  ESV     FOXF     GIG    ...          QEP     SABR       SE  \
# Date                                     ...
# 2016-09-21  13016900  2623500  545800    ...      5229700  2414400  3646900
# 2016-09-20   7900000    68500  471400    ...      3785500  2466800  3056600
# 2016-09-19   8438400   113400  297900    ...      3774700  3060900  4341800
# 2016-09-16  14007300   308300  583300    ...      6512900  2379300  9275200
# 2016-09-15   8653000   296800  990000    ...      4817500  2352600  4312800
#
# ...

# %%
# A STACK OVERFLOW EXAMPLE OF PULLING INDEX >>>> idx = df[df['BoolCol']].index.tolist() OR df[df['BoolCol'] == True].index.tolist()
# HERE IT'S REDUNDANT BUT KEEPING CODE FOR FUTURE USE
idx= volumes_file[volumes_file.index == '2016-09-21'].index.tolist()
idx
# Out:
# ['2016-09-21']

# %%
# TESTING OUT A SLICING OPERATION WITH CUMSUM THEN PRINTING INTO CUMSUM DF ... WORKING AS ANTICIPATED
#volumes_cum_sum['AKS']= volumes_file.ix[:test_aks]['AKS'].cumsum()
# Out:
#                    AKS         AM         COG         CPE           D  \
# Date
# 2016-09-21  24092400.0   333100.0   6097900.0   4104500.0   2784400.0
# 2016-09-20  30403600.0   824000.0  11577700.0   7030600.0   5216000.0
# 2016-09-19  41191800.0  1257200.0  15074800.0  10046300.0   7349300.0
# 2016-09-16  52398700.0  1902400.0  22085000.0  17158000.0  12093700.0
# 2016-09-15  64804100.0  2252800.0  27507800.0  22329700.0  14238800.0
#
#                    DVN        EQT         ESV       FOXF        GIG  \
# Date
# 2016-09-21   4746400.0  1729000.0  13016900.0  2623500.0   545800.0
# 2016-09-20   8633900.0  3483300.0  20916900.0  2692000.0  1017200.0
# 2016-09-19  12503100.0  4559200.0  29355300.0  2805400.0  1315100.0
# 2016-09-16  18092700.0  6869900.0  43362600.0  3113700.0  1898400.0
# 2016-09-15  22563200.0  8063300.0  52015600.0  3410500.0  2888400.0
#
#               ...              PE       PRAH         QEP        SABR  \
# Date          ...
# ...

# %%
len(stats_file.Day_Prior)
#len(volumes_cum_sum.columns)
# Out:
# 23

# %%
# SETTING INTO PRACTICE UTILIZING THE EXAMPLE CODE BELOW TO REVERSE THE DATAFRAME COL SO THAT CUMSUM STARTS FROM LATEST DATE
# df['C'] = df.ix[::-1, 'A'].cumsum()[::-1]
cumsum_dict= {}
for i in range(len(volumes_cum_sum.columns)):
    ticker = volumes_cum_sum.columns[i]
    adj_date = stats_file.Adj_Date[i]
    adj_date_string = datetime.strftime(adj_date, '%Y-%m-%d')
    period_post_deal = pd.DataFrame(volumes_file.ix[:adj_date_string][ticker])
    volumes_cum_sum[ticker]= period_post_deal.ix[::-1][ticker].cumsum()[::-1]

# %%
# CUMSUM VOL TABLE
#volumes_cum_sum.head()
# Out:
# {}

# %%
# Converting to percent of deal volume
volumes_cum_prcnt = volumes_cum_sum.copy()

for i in range(len(volumes_cum_sum.columns)):
    ticker = volumes_cum_sum.columns[i]
    tran_vol = stats_file.Transaction_Volume[i]
    volumes_cum_prcnt[ticker]= volumes_cum_sum[ticker] / (tran_vol*1000000)

# %%
volumes_cum_prcnt.head()
# Out:
#                   AKS        AM        COG        CPE          D        DVN  \
# Date
# 2016-09-21  23.229515  7.797207  18.713939  36.221849  32.612402  20.359825
# 2016-09-20  22.826632  7.756585  18.593427  35.951816  32.339422  20.300047
# 2016-09-19  22.721094  7.696720  18.485130  35.759309  32.101029  20.251086
# 2016-09-16  22.540689  7.643890  18.416018  35.560908  31.891882  20.202355
# 2016-09-15  22.353283  7.565207  18.277476  35.093033  31.426745  20.131957
#
#                   EQT        ESV      FOXF       GIG    ...            PE  \
# Date                                                    ...
# 2016-09-21  36.048656  18.236865  11.39232  4.372288    ...     18.004156
# 2016-09-20  35.817351  18.008498  10.34292  4.330939    ...     17.857663
# 2016-09-19  35.582662  17.869902  10.31552  4.295227    ...     17.749663
# 2016-09-16  35.438729  17.721860  10.27016  4.272659    ...     17.612732
# ...

# %%
# NOT CLEAR WHETHER THIS DROPNA SHOULD DROP THE NAN'S
volumes_cum_prcnt.dropna(how = "all")
volumes_cum_prcnt.head()
# Out:
#                   AKS        AM        COG        CPE          D        DVN  \
# Date
# 2016-09-21  23.229515  7.797207  18.713939  36.221849  32.612402  20.359825
# 2016-09-20  22.826632  7.756585  18.593427  35.951816  32.339422  20.300047
# 2016-09-19  22.721094  7.696720  18.485130  35.759309  32.101029  20.251086
# 2016-09-16  22.540689  7.643890  18.416018  35.560908  31.891882  20.202355
# 2016-09-15  22.353283  7.565207  18.277476  35.093033  31.426745  20.131957
#
#                   EQT        ESV      FOXF       GIG    ...            PE  \
# Date                                                    ...
# 2016-09-21  36.048656  18.236865  11.39232  4.372288    ...     18.004156
# 2016-09-20  35.817351  18.008498  10.34292  4.330939    ...     17.857663
# 2016-09-19  35.582662  17.869902  10.31552  4.295227    ...     17.749663
# 2016-09-16  35.438729  17.721860  10.27016  4.272659    ...     17.612732
# ...

# %%
comp_ratios_norm = pd.DataFrame()
type(comp_ratios_norm)
# Out:
# pandas.core.frame.DataFrame

# %%
comp_ratios_norm = pd.DataFrame(comp_ratios_normed)

# %%
# CREATING A NEW DF WITH COMP RATIOS FROM THE TRANSACTION DATE ON
for i in range(len(comp_ratios.columns)):
    ticker = comp_ratios.columns[i]
    date_ = stats_file.Date[i]
    if date_ == '5/1/16':
        date_ = '5/2/16'
    period_post_deal = pd.DataFrame(comp_ratios_norm.ix[:date_][ticker])
    comp_ratios[ticker] = period_post_deal

# %%
comp_ratios.head()
# Out:
#               AKS        AM       COG      CPE        D      DVN      EQT  \
# Date
# 9/21/16  0.965805   0.59812  0.952408  1.23441  1.03744  1.51294  1.26093
# 9/20/16  0.946489   0.60362  0.943042  1.19418  1.04086  1.56271  1.23992
# 9/19/16  0.936917  0.593216   0.95662  1.18759  1.03802  1.53188  1.21705
# 9/16/16  0.946177  0.577637  0.964404  1.18979   1.0362  1.56016  1.19394
# 9/15/16  0.925936  0.592267  0.980836   1.1872  1.03593  1.52072  1.14058
#
#               ESV     FOXF       GIG   ...           PE     PRAH       QEP  \
# Date                                   ...
# 9/21/16  0.785036  1.14372  0.836581   ...     0.845736  1.22687  0.683018
# 9/20/16  0.787725  1.08396  0.813415   ...     0.874222  1.23092  0.679419
# 9/19/16  0.773286  1.08825  0.783278   ...     0.879074  1.21767  0.669801
# 9/16/16  0.780499  1.10701  0.759595   ...     0.877453  1.22244  0.663546
# 9/15/16   0.78266  1.10062  0.759536   ...     0.879362  1.21056  0.669962
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
LARGE_FIGSIZE = (24, 16)
import matplotlib; matplotlib.style.use('ggplot')
comp_ratios.plot()

# %%
cum_vol_cols = ['AKS_vol','AM_vol',
'COG_vol',
'CPE_vol',
'D_vol',
'DVN_vol',
'EQT_vol',
'ESV_vol',
'FOXF_vol',
'GIG_vol',
'GPOR_vol',
'HES_vol',
'MTDR_vol',
'PE_vol',
'PRAH_vol',
'QEP_vol',
'SABR_vol',
'SE_vol',
'SPWH_vol',
'SRC_vol',
'SWN_vol',
'SYRG_vol',
'WGP_vol']

cum_vol_deals_done = ['AKS_vol','AM_vol',
'DVN_vol',
'FOXF_vol',
'GIG_vol',
'GPOR_vol',
'HES_vol',
'MTDR_vol',
'PE_vol',
'QEP_vol',
'SABR_vol',
'SE_vol',
'SPWH_vol',
'SRC_vol',
'SWN_vol',
'WGP_vol']

avg_price_deals_done = ['AKS','AM',
'DVN',
'FOXF',
'GIG',
'GPOR',
'HES',
'MTDR',
'PE',
'QEP',
'SABR',
'SE',
'SPWH',
'SRC',
'SWN',
'WGP']

#avg_cum_vol_deals_done = avg_cum_vol_deals_done.drop(['COG',
#'CPE',
#'D',
#'EQT',
#'ESV', 
#'PRAH',
#'SYRG'], axis =1)

# %%
# DATA WRANGLING TO SET UP A NEW DF WITH ONLY THE DEALS DONE (PRELIMINARY STEPS TO AVERAGING)
#cum_vol_and_prices.plot.scatter('AKS_cum', 'AKS')
#cum_vol_and_prices = pd.concat([prices_ratio,cum_vol], axis =0)
#len(prices_ratio)

#cum_vol_and_prices = pd.DataFrame(comp_ratios['AKS')
#cum_vol_and_prices['AKS_cum'] = cum_vol['AKS_cum']
#cum_vol= pd.DataFrame(volumes_cum_prcnt['AKS'])

#cum_vol_and_prices.index
#prices_ratio.index
#cum_vol
#cum_vol_and_prices
#comp_ratios.iloc[:,:]
#cum_vol_and_comps = pd.concat([comp_ratios,volumes_cum_prcnt], axis =1)
#cum_vol_and_prices
#volumes_cum_prcnt.columns = cum_vol_cols
#volumes_cum_prcnt.T.index = cum_vol_cols
#volumes_cum_percent = pd.DataFrame(volumes_cum_prcnt, columns = cum_vol_cols)
#cum_vol_and_prices
#volumes_cum_prcnt.index 
#cum_vol_and_comps.columns
#type(cum_vol_cols)
#comp_ratios.index
#cum_vol_and_comps['SRC_vol']= cum_vol_and_comps['SRC_vol']*(11/30)
#avg_cum_vol = cum_vol_and_comps[cum_vol_cols]

#avg_cum_vol_deals_done.columns
avg_deals_done_price =avg_deals_done[['AKS','AM',
'DVN',
'FOXF',
'GIG',
'GPOR',
'HES',
'MTDR',
'PE',
'QEP',
'SABR',
'SE',
'SPWH',
'SRC',
'SWN',
'WGP']]
#avg_deals_done_price.mean(axis=1)

# %%
# 10%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='AKS_vol',y='AKS',ax=ax, kind='scatter')
ax.set_xlim(0,7)
ax.set_ylim(.75,1)
#cum_vol_and_comps.plot.scatter('AKS_vol', 'AKS')
# Out:
# (0.75, 1)

# %%
# 10%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='AM_vol',y='AM',ax=ax, kind='scatter')
ax.set_xlim(0,7)
ax.set_ylim(.65,.9)
# Out:
# (0.65, 0.9)

# %%
# 0%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='COG_vol',y='COG',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.9,1.05)
# Out:
# (0.9, 1.05)

# %%
# 0%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='CPE_vol',y='CPE',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.95,1.1)
# Out:
# (0.95, 1.1)

# %%
# 0%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='D_vol',y='D',ax=ax, kind='scatter')
ax.set_xlim(0,6)
# Out:
# (0, 6)

# %%
# 10%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='DVN_vol',y='DVN',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.85,1.1)
# Out:
# (0.85, 1.1)

# %%
# 0%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='EQT_vol',y='EQT',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.95,1.1)
# Out:
# (0.95, 1.1)

# %%
# 0%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='ESV_vol',y='ESV',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.9,1.1)
# Out:
# (0.9, 1.1)

# %%
# 12%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='FOXF_vol',y='FOXF',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.85,1.1)
# Out:
# (0.85, 1.1)

# %%
# 40%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='GIG_vol',y='GIG',ax=ax, kind='scatter')
ax.set_xlim(0,6)
# Out:
# (0, 6)

# %%
# 0%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='GPOR_vol',y='GPOR',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.85,1.05)
# Out:
# (0.85, 1.05)

# %%
# 4%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='HES_vol',y='HES',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.85,1.1)
# Out:
# (0.85, 1.1)

# %%
# 0%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='MTDR_vol',y='MTDR',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.85,1.1)
# Out:
# (0.85, 1.1)

# %%
# 0%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='PE_vol',y='PE',ax=ax, kind='scatter')
ax.set_xlim(0,6)
# Out:
# (0, 6)

# %%
# 0%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='PRAH_vol',y='PRAH',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.9,1.1)
# Out:
# (0.9, 1.1)

# %%
# 12%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='QEP_vol',y='QEP',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.80,1.0)
# Out:
# (0.8, 1.0)

# %%
# 0%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='SABR_vol',y='SABR',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.9,1.05)
# Out:
# (0.9, 1.05)

# %%
# 4%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='SE_vol',y='SE',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.9,1.05)
# Out:
# (0.9, 1.05)

# %%
# 20%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='SPWH_vol',y='SPWH',ax=ax, kind='scatter')
ax.set_xlim(0,6)
# Out:
# (0, 6)

# %%
# 5%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='SRC_vol',y='SRC',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.9,1.05)
# Out:
# (0.9, 1.05)

# %%
# 3%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='SWN_vol',y='SWN',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.85,1.1)
# Out:
# (0.85, 1.1)

# %%
# LIKELY INNER-DAY 
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='SYRG_vol',y='SYRG',ax=ax, kind='scatter')
ax.set_xlim(0,6)
ax.set_ylim(.8,1.1)
# Out:
# (0.8, 1.1)

# %%
# 12%
fig = plt.figure()
ax = plt.subplot(111)
cum_vol_and_comps.plot(x='WGP_vol',y='WGP',ax=ax, kind='scatter')
ax.set_xlim(0,6)
# Out:
# (0, 6)

# %%
batch_2 = ("CTRE","SBRA",
"DERM","BNCN",
"CARA","DVAX",
"EPZM","ACAD",
"GNCA","HZNP",
"TMHC","HDP",
"ITCI","BNCN",
"ITEK",
"BNCN","LOXO",
"MGNX","DATA",
"NDRM","ARDX",
"NWHM","TPH",
"ONCE","KPTI",
"OTIC","BLCM",
"PARR","BMRC",
"QTNT","FLXN",
"QTWO","RARE",
"RAS","ACW",
"RLGT","GNCA",
"RVNC","ARDX",
"STKL","TTPH",
"TRVN",
"TTOO","SMLP",
"TXMD","XLRN",
"ZEN",
"ZGNX")
long_shorts = ("CTRE","SBRA",
"DERM,BNCN",
"CARA,DVAX",
"EPZM","ACAD",
"GNCA","HZNP",
"BNCN","ITCI",
"ITCI","BNCN",
"DBVT","ITEK",
"ITEK","DBVT",
"BNCN","LOXO",
"LOXO","BNCN",
"MGNX","DATA",
"NDRM","ARDX",
"NWHM","TPH",
"ONCE","KPTI",
"OTIC","BLCM",
"PARR","BMRC",
"QTNT","FLXN",
"QTWO","RARE",
"RAS","ACW",
"RLGT","GNCA",
"RVNC","ARDX",
"STKL","TTPH",
"TRVN","ITCI",
"TTOO","SMLP",
"TXMD","XLRN",
"ZEN","XLRN",
"ZGNX","XLRN")
# CHECK THESE LAST 3 SHORTS

longs = ("CTRE",
"DERM",
"CARA",
"EPZM",
"GNCA",
"HDP",
"BNCN",
"ITCI",
"DBVT",
"ITEK",
"BNCN",
"LOXO",
"MGNX",
"NDRM",
"NWHM",
"ONCE",
"OTIC",
"PARR",
"QTNT",
"QTWO",
"RAS",
"RLGT",
"RVNC",
"STKL",
"TRVN",
"TTOO",
"TXMD",
"ZEN",
"ZGNX")

# %%
#prices_file = pd.read_csv('Prices_table.csv')
#prices_file2= prices_file2.drop(["Volume","Adj Close","Open","High","Low","Close"], axis =1)
#volumes_file2=  prices_file2.copy()
for ticker in batch_2:
    pricefiles2.append(ticker+"prices.csv")
    temp_prices_file = pd.read_csv(ticker+"prices.csv")
    temp_prices_file.index = temp_prices_file['Date']
    prices_file2[ticker] = temp_prices_file['Adj Close']
    volumes_file2[ticker] = temp_prices_file['Volume']

# %%
volumes_file2= volumes_file2[["CTRE",
"DERM",
"CARA",
"EPZM",
"GNCA",
"BNCN",
"ITCI",
"DBVT",
"ITEK",
"BNCN",
"LOXO",
"MGNX",
"NDRM",
"NWHM",
"ONCE",
"OTIC",
"PARR",
"QTNT",
"QTWO",
"RAS",
"RLGT",
"RVNC",
"STKL",
"TRVN",
"TTOO",
"TXMD",
"ZEN",
"ZGNX"]]

# %%
# SAMPLE CODE ...First 4 rows and first 2 columns
#df.iloc[0:4, 0:2]
#volumes_file2= volumes_file2.drop(volumes_file2.iloc[:,1:2], axis= 1)
#volumes_file2= volumes_file2.sort(axis=1)
#bncn= volumes_file2.iloc[:,1:2]
#volumes_file2.loc['BNCN']= volumes_file2_.iloc[:,0]
volumes_file2
# Out:
#                 BNCN       CARA       CTRE       DBVT      DERM      EPZM  \
# Date
# 2016-04-01   88900.0   638100.0   448700.0    91900.0  237900.0  363200.0
# 2016-03-31   81700.0   481500.0   260800.0    37800.0  295700.0  596500.0
# 2016-03-30   87700.0   633500.0   332900.0    72900.0  234000.0  363400.0
# 2016-03-29   77700.0   528100.0   802600.0    37900.0  364800.0  387500.0
# 2016-03-28   79600.0   357000.0   413800.0    39800.0  162600.0  142700.0
# 2016-03-24   68300.0   797100.0   559700.0    46900.0  141600.0  266800.0
# 2016-03-23   67700.0   854700.0   889200.0    52900.0  173300.0  235200.0
# 2016-03-22   62800.0  1038400.0  7408500.0    32200.0  323400.0  380400.0
# 2016-03-21   45100.0  3153200.0   118200.0    77000.0  402300.0  367100.0
# 2016-03-18  218100.0   646700.0   226900.0   108000.0  356500.0  651400.0
# 2016-03-17  258400.0   666600.0   140800.0   137300.0  660000.0  359700.0
# 2016-03-16   88400.0   611100.0   188700.0    59800.0  223800.0  200300.0
# ...

# %%
stats_table2 = pd.read_csv('stats_table2.csv')

# %%
db = sqlite3.connect("prices_csv.sqlite")
volumes_file.to_sql('volumes', db)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1127-3f8921283145> in <module>()
#       1 db = sqlite3.connect("prices_csv.sqlite")
# ----> 2 volumes_file.to_sql('volumes', db)
#
# /Users/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in to_sql(self, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#    1163         sql.to_sql(self, name, con, flavor=flavor, schema=schema,
#    1164                    if_exists=if_exists, index=index, index_label=index_label,
# -> 1165                    chunksize=chunksize, dtype=dtype)
#    1166
#    1167     def to_pickle(self, path):
#
# /Users/anaconda/lib/python3.5/site-packages/pandas/io/sql.py in to_sql(frame, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#     569     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
# ...

# %%
db = sqlite3.connect("prices_csv.sqlite")
stats_file.to_sql('stats', db)

# %%
table_name1 = 'prices'
col_name = 'AM_CPE'
field_type = 'INTEGER'
conn = sqlite3.connect('prices_csv.sqlite')```
c = conn.cursor()
c.execute("ALTER TABLE {tn} ADD COLUMN '{cn}' {ft}"\
            .format(tn=table_name1, cn=col_name, ft=field_type))
conn.commit()
conn.close()

# %%
db = sqlite3.connect("prices_csv.sqlite")
c = db.cursor()
#        c.execute("INSERT OR IGNORE INTO {tn} ({cn}) VALUES ({an})".\
#        format(tn=table_name1, cn=col_name, an=am_cpe))
c.executemany(''' INSERT INTO prices(am_cpe) VALUES (?)''', am_cpe)
#cursor.executemany(''' INSERT INTO users(name, phone, email, password) VALUES(?,?,?,?)''', users)

db.commit()
db.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-1aeaf41e2f94> in <module>()
#       3 #        c.execute("INSERT OR IGNORE INTO {tn} ({cn}) VALUES ({an})".\
#       4 #        format(tn=table_name1, cn=col_name, an=am_cpe))
# ----> 5 c.executemany(''' INSERT INTO prices(am_cpe) VALUES (?)''', am_cpe)
#       6 #cursor.executemany(''' INSERT INTO users(name, phone, email, password) VALUES(?,?,?,?)''', users)
#       7
#
# ValueError: parameters are of unsupported type
