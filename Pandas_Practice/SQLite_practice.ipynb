# %%
import sqlite3
sqlite_file = 'practice_db_12_28.sqlite'

# %%
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# %%
table_name1 = 'prices_table'  # name of the table to be created
table_name2 = 'volumes_table'  # name of the table to be created
new_field = 'HES' # name of the column
field_type = 'INTEGER'  # column data type

# Connecting to the database file
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# Creating a new SQLite table with 1 column
c.execute('CREATE TABLE {tn} ({nf} {ft})'\
        .format(tn=table_name1, nf=new_field, ft=field_type))

# Creating a second table with 1 column and set it as PRIMARY KEY
# note that PRIMARY KEY column must consist of unique values!
c.execute('CREATE TABLE {tn} ({nf} {ft} PRIMARY KEY)'\
        .format(tn=table_name2, nf=new_field, ft=field_type))

# Committing changes and closing the connection to the database file
conn.commit()
conn.close()

# %%
# TESTING 1 VALUE INPUT
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()
c.execute("INSERT OR IGNORE INTO {tn} ({cn}) VALUES (123456)".\
        format(tn=table_name1, cn=new_field))
conn.commit()
conn.close()

# TUTORIAL CODE
#c.execute("INSERT OR IGNORE INTO {tn} ({idf}, {cn}) VALUES (123456, 'test')".\
 #       format(tn=table_name, idf=id_column, cn=column_name))

# %%
import pandas as pd
import numpy as np
prices_file = pd.read_csv('Prices_table.csv')

# %%
prices_file.head()
# Out:
#       Date   AKS         AM        COG    CPE          D        DVN  \
# 0  9/21/16  4.72  26.680000  25.240000  14.90  76.750000  42.169998
# 1  9/20/16  4.30  25.570000  24.520000  14.15  75.629997  40.660000
# 2  9/19/16  4.30  25.520000  24.350000  14.37  75.900002  40.849998
# 3  9/16/16  4.11  25.040001  24.299999  14.48  75.059998  40.990002
# 4  9/15/16  4.06  25.160000  25.040001  14.19  74.449997  40.900002
#
#          EQT   ESV       FOXF     ...            QEP       SABR         SE  \
# 0  74.160004  7.09  21.820000     ...      18.070000  27.070000  42.669998
# 1  72.760002  6.64  20.450001     ...      17.070000  26.709999  42.000000
# 2  71.230003  6.74  20.530001     ...      17.090000  26.920000  42.310001
# 3  70.510002  6.87  20.879999     ...      17.059999  26.870000  42.459999
# 4  71.440002  6.99  20.840000     ...      16.879999  27.437256  42.220001
#
#    SPWH    SRC    SWN  SYRG        WGP    USO         SPY
# 0  9.82  13.38  14.68  6.30  39.630001  10.40  215.820007
# 1  9.64  13.15  14.25  5.88  38.660000  10.07  213.419998
# 2  9.78  13.11  13.86  6.08  38.180000   9.98  213.410004
# 3  9.77  12.96  13.68  6.14  37.549999  10.00  213.369995
# 4  9.67  13.04  14.08  6.23  37.000000  10.14  214.197992
#
# [5 rows x 26 columns]

# %%
# Create a db file name database.db ### THIS CODE BLOCK WAS SUBSEQUENTLY COPIED IN TO THE NOTEBOOK AS A MORE EFFICIENT MANNTER OF LOADING IN
db = sqlite3.connect("prices_csv.sqlite")
prices_file.to_sql('prices', db)

# %%
prices_file.info
# Out:
# <bound method DataFrame.info of          Date   AKS         AM        COG    CPE          D        DVN  \
# 0     9/21/16  4.72  26.680000  25.240000  14.90  76.750000  42.169998
# 1     9/20/16  4.30  25.570000  24.520000  14.15  75.629997  40.660000
# 2     9/19/16  4.30  25.520000  24.350000  14.37  75.900002  40.849998
# 230  27.065820  11.36   9.617181  11.67  11.10  40.586920  14.51  200.933416
# 231  27.293742  12.10   9.455147  12.40  10.86  41.485029  14.43  197.595305
# 232  27.521665  12.11   9.540930  13.09  11.28  43.204817  14.73  198.828741
# 233  27.645124  12.13   9.512335  12.99  11.16  43.586989  14.83  199.083255
# 234  27.873046  12.10   9.312177  13.14  11.35  43.787633  15.22  198.985372
#
# [235 rows x 26 columns]>

# %%
#temp_ticker= prices_file.columns[:]
#temp_ticker[1]
#temp_prices = prices_file[1]
#first_hes_price = hes_prices[0:2]
#first_hes_price
#prices_file.columns[13:]

#prices_file[temp_ticker[2]]
#for t in range(len(tickers])):
#    print(tickers[t])
#tickers[0]
#prices_file[tickers[0]]
range(len(tickers))
# Out:
# range(0, 26)

# %%
dummy_field = "Date_"
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# Workaround for having executed part of script and generated columns then needing to finish latter half of prices_file

c.execute('CREATE TABLE {tn} ({nf} {ft})'\
        .format(tn=table_name1, nf=dummy_field, ft=field_type))

conn.commit()
conn.close()

# %%
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# Workaround for having executed part of script and generated columns then needing to finish latter half of prices_file

c.execute('CREATE TABLE {tn} ({nf} {ft})'\
        .format(tn=table_name1, nf=dummy_field, ft=field_type))

conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-113-f03deac63971> in <module>()
#       5 # Workaround for having executed part of script and generated columns then needing to finish latter half of prices_file
#       6
# ----> 7 c.execute('DROP COLUMN {ft}'        .format(ft=field_type_drop))
#       8
#       9 conn.commit()
#
# OperationalError: near "COLUMN": syntax error

# %%
tickers = prices_file.columns

# %%
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

for t in range(len(prices_file[tickers])):
           c.execute("ALTER TABLE {tn} ADD COLUMN '{cn}' {ft}"\
            .format(tn=table_name1, cn=prices_file.columns[t], ft=field_type))
conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-114-7a98380847c7> in <module>()
#       6     temp_ticker = prices_file.columns[z]
#       7     for t in range(len(prices_file[temp_ticker])):
# ----> 8            c.execute("ALTER TABLE {tn} ADD COLUMN '{cn}' {ft}"            .format(tn=table_name1, cn=prices_file.columns[z], ft=temp_ticker[t]))
#       9 conn.commit()
#      10 conn.close()
#
# OperationalError: duplicate column name: AKS

# %%
#temp_ticker = tickers[1]
#len(prices_file[temp_ticker])
#temp_ticker = tickers[0]
prices_file[tickers[1]][1]
# Out:
# 4.2999999999999998

# %%
# RAPPING INSERT WITH A LOOP
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

for i in range(len(tickers)):
    temp_ticker = tickers[i]
    for t in range(len(prices_file[temp_ticker])):
        c.execute("INSERT OR IGNORE INTO {tn} ({cn}) VALUES ({an})".\
        format(tn=table_name1, cn=temp_ticker, an=prices_file[temp_ticker[t]]))
conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-177-4cfeb6c937f9> in <module>()
#       5 for i in range(len(tickers)):
#       6     for t in range(len(prices_file[tickers[i]])):
# ----> 7         c.execute("INSERT OR IGNORE INTO {tn} ({cn}) VALUES ({an})".        format(tn=table_name1, cn=temp_ticker, an=prices_file[tickers[i][t]]))
#       8 conn.commit()
#       9 conn.close()
#
# OperationalError: near "76.750000": syntax error
